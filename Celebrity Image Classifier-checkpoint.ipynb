# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %% [markdown]
# Data Cleaning

# %%
# detect the face ond eyes ond crop that imgage and store it in some different folder
img = cv2.imread("C:/Users/Jagruth/Desktop/Celebrity Image Classifier/images/mariasharapova-cropped_13pnd8p3yjgu6zv7u78uielc9.jpg")

# %%
img.shape
# Out:
# (731, 1300, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (731, 1300)

# %%
plt.imshow(gray, cmap='gray')

# %%
# to detect face and eyes of any image so that we can crop those images
# haar Cascade Classifier
face_cascade = cv2.CascadeClassifier('/content/gdrive/MyDrive/Colab Notebooks/Celebrity Image Classifier/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('/content/gdrive/MyDrive/Colab Notebooks/Celebrity Image Classifier/haarcascades/haarcascade_eye.xml')

# %%
faces=face_cascade.detectMultiScale(gray,1,3,5)
faces
(x,y,w,h)=faces[0]
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-8-8eb3c8c1a6b1> in <module>
# ----> 1 faces=face_cascade.detectMultiScale(gray,1,3,5)
#       2 faces
#       3 (x,y,w,h)=faces[0]
#
# error: OpenCV(4.6.0) /io/opencv/modules/objdetect/src/cascadedetect.cpp:1389: error: (-215:Assertion failed) scaleFactor > 1 && _image.depth() == CV_8U in function 'detectMultiScale'
